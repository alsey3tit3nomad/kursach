# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('main20230108-icews-events.xlsx')
df.head()
df =df[df['Country'] == 'Russian Federation']

# %%
df.head()
import datetime as dt
df['Event Date'] = pd.to_datetime(df['Event Date'])

# %%
# print(len(set(df['Event Text'].values)), sep='\n')
for i in set(df['Event Text'].values):
    print(i)
# df[df['Event Text'] == 'Deny responsibility']
# Out:
# Meet at a 'third' location
# Express intent to meet or negotiate
# Make empathetic comment
# Make pessimistic comment
# Mediate
# Threaten
# Provide aid
# Deny responsibility
# Demobilize armed forces
# Impose state of emergency or martial law
# fight with artillery and tanks
# Reject proposal to meet, discuss, or negotiate
# Appeal for diplomatic cooperation (such as policy support)
# Threaten with sanctions, boycott, embargo
# Bring lawsuit against
# Abduct, hijack, or take hostage
# Appeal for de-escalation of military engagement
# Make a visit
# Engage in diplomatic cooperation
# Accuse of aggression
# Reduce relations
# Make an appeal or request
# Physically assault
# Express intent to ease administrative sanctions
# Impose administrative sanctions
# Engage in negotiation
# Employ aerial weapons
# Host a visit
# Engage in symbolic act
# Mobilize or increase armed forces
# Increase police alert status
# Make statement
# Arrest, detain, or charge with legal action
# Consult
# Use unconventional violence
# Occupy territory
# Yield
# Consider policy option
# Provide military aid
# fight with small arms and light weapons
# Accuse of war crimes
# Appeal to others to settle dispute
# Provide humanitarian aid
# Refuse to de-escalate military engagement
# Reject judicial cooperation
# Reject plan, agreement to settle dispute
# Declare truce, ceasefire
# Confiscate property
# Reduce or stop material aid
# Praise or endorse
# Criticize or denounce
# Demand
# Discuss by telephone
# Demonstrate or rally
# Impose embargo, boycott, or sanctions
# Sign formal agreement
# Express intent to provide economic aid
# Use conventional military force
# Retreat or surrender militarily
# Return, release person(s)
# Investigate
# Accuse
# Use tactics of violent repression
# Express intent to engage in diplomatic cooperation (such as policy support)
# Violate ceasefire
# Express intent to cooperate
# Receive deployment of peacekeepers
# Express intent to provide military aid
# Reject
# Demand de-escalation of military engagement
# Appeal for easing of economic sanctions, boycott, or embargo
# Express intent to release persons or property
# Conduct suicide, car, or other non-military bombing
# Grant diplomatic recognition
# Express accord
# Make optimistic comment
# Express intent to cooperate militarily
# Expel or deport individuals

# %%
# df = df[df['Event Text']=='Demonstrate or rally']
a = open('for_misha.txt', 'w+')
for i in set(df['Event Text'].values):
    a.write(i+'\n')
# for i in a:
print(a.read())
a.close()
print(df.shape)
# Out:
# (1193, 20)

# %%
print(df['Event Date'].max())
print(df['Event Date'].min())
# Out:
# 2023-01-09 00:00:00
# 2022-10-14 00:00:00

# %%
# df1 = df.groupby('Event Text')
df1 = df

# %%
# df1['Cul'] = df['Event Text'].value_counts()
# df1.head()
event_counts = df['Event Text'].value_counts()

df['Event Count'] = df['Event Text'].map(event_counts)

df1 = df.sort_values(by='Event Count', ascending=False)
df1
# Out:
#                   Event ID Event Date                  Source Name  \
# 244    3754-05-13 00:00:00 2022-10-20                United States
# 77                37542842 2022-10-19               Vladimir Putin
# 15593             37552524 2023-01-09                Dmitry Peskov
# 100               37543110 2022-10-19    Foreign Affairs (Ukraine)
# 181               37539267 2022-10-20        Party Member (Russia)
# ...                    ...        ...                          ...
# 13674             37550454 2023-01-08             Police (Armenia)
# 489               37541730 2022-10-20                       Russia
# 8110   3754-10-10 00:00:00 2023-01-04               United Nations
# 7732              37535602 2023-01-04     Foreign Affairs (Israel)
# 13914             37550739 2023-01-08  Reserve Personnel (Ukraine)
#
#                                           Source Sectors      Source Country  \
# 244                                                  NaN       United States
# 77     (National) Major Party,Center Right,Elite,Exec...  Russian Federation
# 15593  Executive,Executive Office,Government,Media,So...  Russian Federation
# 100                Executive,Foreign Ministry,Government             Ukraine
# 181                                              Parties  Russian Federation
# ...                                                  ...                 ...
# 13674                                  Government,Police             Armenia
# 489                                                  NaN  Russian Federation
# 8110   Global,Global Diplomatic IGOs,International Go...                 NaN
# 7732               Executive,Foreign Ministry,Government              Israel
# 13914                                Government,Military             Ukraine
#
#                                            Event Text  CAMEO Code  Intensity  \
# 244                                    Make statement          10        0.0
# 77                                     Make statement          10        0.0
# 15593                                  Make statement          10        0.0
# 100                                    Make statement          10        0.0
# 181                                    Make statement          10        0.0
# ...                                               ...         ...        ...
# 13674               Use tactics of violent repression         175       -9.0
# 489                       Expel or deport individuals         174       -5.0
# 8110                             Accuse of war crimes        1124       -2.0
# 7732   Reject proposal to meet, discuss, or negotiate         125       -5.0
# 13914                             Confiscate property        1711       -9.2
#
#                                   Target Name  \
# 244                                    Russia
# 77                         Military (Ukraine)
# 15593                                  Russia
# 100                      Government (Ukraine)
# 181                  Lawyer/Attorney (Russia)
# ...                                       ...
# 13674                     Protester (Armenia)
# 489                          Citizen (Russia)
# 8110                        Military (Russia)
# 7732                                   Russia
# 13914  Armed Forces of the Russian Federation
#
#                                          Target Sectors  ...    Story ID  \
# 244                                                 NaN  ...  56628059.0
# 77                                  Government,Military  ...  56633384.0
# 15593                                               NaN  ...  56654450.0
# 100                                          Government  ...  56635119.0
# 181                                        Legal,Social  ...  56624453.0
# ...                                                 ...  ...         ...
# 13674  Dissident,Protestors / Popular Opposition / Mobs  ...  56650364.0
# 489       General Population / Civilian / Social,Social  ...  56631567.0
# 8110                                Government,Military  ...  56623000.0
# 7732                                                NaN  ...  56614421.0
# 13914                               Government,Military  ...  56651019.0
#
#        Sentence Number              Publisher            City District  \
# 244                4.0                Unknown          Moscow      NaN
# 77                 1.0           The Scotsman         Kherson      NaN
# 15593              2.0           Reuters News  Moscow Kremlin      NaN
# 100                6.0     Al Jazeera English          Moscow      NaN
# 181                6.0     Al Jazeera English             NaN      NaN
# ...                ...                    ...             ...      ...
# 13674              1.0           Reuters News          Moscow      NaN
# 489                3.0  Interfax News Service    Ovsyannikova      NaN
# 8110               5.0                Unknown          Moscow      NaN
# 7732               3.0                Unknown             NaN      NaN
# 13914              1.0                Unknown         Bakhmut      NaN
#
#                     Province             Country Latitude  Longitude  \
# 244                   Moskva  Russian Federation  55.7522    37.6156
# 77     Orenburgskaya Oblast'  Russian Federation  51.4000    58.6167
# 15593    Moskovskaya Oblast'  Russian Federation  55.7517    37.6178
# 100                   Moskva  Russian Federation  55.7522    37.6156
# 181                      NaN  Russian Federation  55.7522    37.6156
# ...                      ...                 ...      ...        ...
# 13674                 Moskva  Russian Federation  55.7522    37.6156
# 489        Tul'skaya Oblast'  Russian Federation  53.4834    36.6347
# 8110                  Moskva  Russian Federation  55.7522    37.6156
# 7732                     NaN  Russian Federation  55.7522    37.6156
# 13914    Kaluzhskaya Oblast'  Russian Federation  53.9531    34.9506
#
#        Event Count
# 244            241
# 77             241
# 15593          241
# 100            241
# 181            241
# ...            ...
# 13674            1
# 489              1
# 8110             1
# 7732             1
# 13914            1
#
# [1193 rows x 21 columns]

# %%
df['Event Date'].min()
# '2023-01-09 00:00:00'
# Out:
# Timestamp('2022-10-14 00:00:00')

# %%
df_2 = pd.read_table('events.2023.20230106.tab')
df_2
# Out:
#       Event ID  Event Date                                        Source Name  \
# 0     37530852  2023-01-01          Defense / Security Ministry (South Korea)
# 1     37530790  2023-01-01              Defense / Security Ministry (Ukraine)
# 2     37530846  2023-01-01               Defense / Security Ministry (Russia)
# 3     37530848  2023-01-01                                  Military (Russia)
# 4     37530847  2023-01-01                                            Ukraine
# ...        ...         ...                                                ...
# 3150  37533802  2023-01-03                                               Iran
# 3151  37532924  2023-01-03                                              India
# 3152  37533049  2023-01-03  Cabinet / Council of Ministers / Advisors (India)
# 3153  37532925  2023-01-03                              Tejashwi Prasad Yadav
# 3154  37533225  2023-01-03                      Oversight Court (South Korea)
#
#                                         Source Sectors      Source Country  \
# 0     Defense / Security Ministry,Executive,Government         South Korea
# 1     Defense / Security Ministry,Executive,Government             Ukraine
# 2     Defense / Security Ministry,Executive,Government  Russian Federation
# 3                                  Government,Military  Russian Federation
# 4                                                  NaN             Ukraine
# ...                                                ...                 ...
# 3150                                               NaN                Iran
# 3151                                               NaN               India
# 3152                      Cabinet,Executive,Government               India
# 3153                                               NaN               India
# 3154                               Government,Judicial         South Korea
#
#                                        Event Text  CAMEO Code  Intensity  \
# 0                                  Make statement          10        0.0
# 1                                  Make statement          10        0.0
# 2                                  Make statement          10        0.0
# 3         fight with small arms and light weapons         193      -10.0
# 4                 Use conventional military force         190      -10.0
# ...                                           ...         ...        ...
# 3150                        Criticize or denounce         111       -2.0
# 3151  Arrest, detain, or charge with legal action         173       -5.0
# 3152                               Make statement          10        0.0
# 3153                         Demonstrate or rally         141       -6.5
# 3154                                       Reject         120       -4.0
#
#             Target Name                                 Target Sectors  \
# 0           North Korea                                            NaN
# 1                Russia                                            NaN
# 2     Military (Russia)                            Government,Military
# 3               Ukraine                                            NaN
# 4                Russia                                            NaN
# ...                 ...                                            ...
# 3150      United States                                            NaN
# 3151   Criminal (India)                    Criminals / Gangs,Dissident
# 3152   Congress (India)         Government,Legislative / Parliamentary
# 3153  Unspecified Actor                                    Unspecified
# 3154    Citizen (China)  General Population / Civilian / Social,Social
#
#           Target Country  Story ID  Sentence Number         Publisher  \
# 0            North Korea  56602964                1           Unknown
# 1     Russian Federation  56602966                6           Unknown
# 2     Russian Federation  56602970                1           Unknown
# 3                Ukraine  56602970                1           Unknown
# 4     Russian Federation  56602970                3           Unknown
# ...                  ...       ...              ...               ...
# 3150       United States  56609506                2          Le Monde
# 3151               India  56609601                5       India Today
# 3152               India  56609603                2       India Today
# 3153                 NaN  56609612                2       India Today
# 3154               China  56609954                1  The Korea Herald
#
#             City         District                 Province  \
# 0            NaN              NaN                      NaN
# 1          Minsk              NaN              Horad Minsk
# 2            NaN              NaN                      NaN
# 3            NaN              NaN                      NaN
# 4            NaN              NaN                      NaN
# ...          ...              ...                      ...
# 3150      Tehran              NaN          Tehran Province
# 3151      Mumbai  Konkan Division     State of Maharashtra
# 3152  Vijayawada              NaN  State of Andhra Pradesh
# 3153       Patna              NaN           State of Bihar
# 3154         NaN              NaN                    Ulsan
#
#                  Country  Latitude  Longitude
# 0            South Korea   37.5683   126.9780
# 1                Belarus   53.9000    27.5667
# 2     Russian Federation   55.7522    37.6156
# 3                Ukraine   50.4547    30.5238
# 4     Russian Federation   55.7522    37.6156
# ...                  ...       ...        ...
# 3150                Iran   35.6944    51.4215
# 3151               India   19.0728    72.8826
# 3152               India   16.5193    80.6305
# 3153               India   25.6022    85.1194
# 3154         South Korea   35.5667   129.2670
#
# [3155 rows x 20 columns]

# %%
import zipfile
with zipfile.ZipFile('try1.zip', 'r') as zip_ref:
    zip_ref.extractall(r'C:\Users\nomad\Downloads\mainpy')

# %%
import os
import zipfile


folder_path = r'C:\Users\nomad\Downloads\mainpy\kursach4'


for filename in os.listdir(folder_path):
    if filename.endswith('.zip'):
        zip_file_path = os.path.join(folder_path, filename)
        print()
        extraction_folder = os.path.join(folder_path, filename[:-4])  # Убираем .zip из имени
        os.makedirs(extraction_folder, exist_ok=True)

        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extraction_folder)


        os.remove(zip_file_path)
        print(f'Распакован и удален: {filename}')

# %%
import os
import zipfile
import shutil

folder_path = r'C:\Users\nomad\Downloads\mainpy\kursach4'

for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            for item1 in os.listdir(item_path):
                file_path = os.path.join(item_path, item1)
                destination_path = os.path.join(folder_path, item1)
                if os.path.exists(destination_path):
                    name, ext = os.path.splitext(item1)
                    a = 1
                    while os.path.exists(destination_path):
                        destination_path = os.path.join(folder_path, f"{name}_{a}{ext}")
                        a += 1
                shutil.move(file_path, destination_path)
            os.rmdir(item_path)
            print(f'Удалена пустая папка: {item_path}')

# %%
folder_path = r'C:\Users\nomad\Downloads\mainpy\kursach4'
list_dataframes = []
from tqdm import tqdm
for file in tqdm(os.listdir(folder_path)):
    filename = os.path.join(folder_path, file)
    if filename.endswith('.tab'):
        df = pd.read_table(filename)
        list_dataframes.append(df)
    elif filename.endswith('.tsv'):
        df = pd.read_csv(filename, sep='\t',)
        list_dataframes.append(df)
# Out:
#  84%|████████▍ | 37/44 [00:52<00:19,  2.75s/it]C:\Users\nomad\AppData\Local\Temp\ipykernel_23620\2835698374.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(filename)
# 100%|██████████| 44/44 [01:08<00:00,  1.55s/it]

# %%
from tqdm.autonotebook import tqdm
tqdm.pandas()

# %%
df_main = pd.concat(list_dataframes)

for i in list_dataframes:
    print(i.head())

len(df_main)
# Out:
#    Event ID  Event Date    Source Name Source Sectors Source Country  \
# 0  37543936  2022-10-13   Saudi Arabia            NaN   Saudi Arabia
# 1  37543653  2022-10-13   Saudi Arabia            NaN   Saudi Arabia
# 2  37542178  2022-10-14         Israel            NaN         Israel
# 3  37542179  2022-10-14  United States            NaN  United States
# 4  37542131  2022-10-14        Ukraine            NaN        Ukraine
#
#                                     Event Text  CAMEO Code  Intensity  \
# 0                          Deny responsibility          16       -5.0
# 1                            Praise or endorse          51        3.4
# 2                                  Provide aid          70        7.0
# 3                         Provide economic aid          71        7.4
# 4  Arrest, detain, or charge with legal action         173       -5.0
#
#           Target Name                               Target Sectors  \
# 0       United States                                          NaN
# 1              Russia                                          NaN
# 2       United States                                          NaN
# 3              Israel                                          NaN
# 4  Volodymyr Zelensky  Elite,Executive,Executive Office,Government
#
#        Target Country  Story ID  Sentence Number           Publisher    City  \
# 0       United States  56635750                4       The Oil Daily     NaN
# 1  Russian Federation  56635751                2       The Oil Daily  Riyadh
# 2       United States  56633048                5  The Jerusalem Post     NaN
# 3              Israel  56633048                6  The Jerusalem Post     NaN
# 4             Ukraine  56633051                2  The Jerusalem Post     NaN
#
#   District           Province        Country  Latitude  Longitude
# 0      NaN    Washington D.C.  United States   38.9171   -77.0003
# 1      NaN  Mintaqat ar Riyad   Saudi Arabia   24.6877    46.7219
# 2      NaN                NaN  United States   38.8951   -77.0364
# 3      NaN                NaN         Israel   31.7790    35.2253
# 4      NaN                NaN        Ukraine   50.4547    30.5238
#    Event ID  Event Date                                Source Name  \
# 0  37571729  2022-10-11                              Mahmoud Abbas
# 1  37571730  2022-10-11                                    Germany
# 2  37571897  2022-10-11            Palestinian Territory, Occupied
# 3  37571796  2022-10-11  Citizen (Palestinian Territory, Occupied)
# 4  37571795  2022-10-11            Palestinian Territory, Occupied
#
#                                   Source Sectors  \
# 0    Elite,Executive,Executive Office,Government
# 1                                            NaN
# 2                                            NaN
# 3  General Population / Civilian / Social,Social
# 4                                            NaN
#
#                    Source Country  \
# 0  Occupied Palestinian Territory
# 1                         Germany
# 2  Occupied Palestinian Territory
# 3  Occupied Palestinian Territory
# 4  Occupied Palestinian Territory
#
#                                           Event Text  CAMEO Code  Intensity  \
# 0                                       Make a visit          42        1.9
# 1                                       Host a visit          43        2.8
# 2                    Use conventional military force         190      -10.0
# 3                                             Accuse         112       -2.0
# 4  Express intent to engage in diplomatic coopera...          32        4.5
#
#                              Target Name  \
# 0                                Germany
# 1                          Mahmoud Abbas
# 2                       Citizen (Israel)
# 3        Palestinian Territory, Occupied
# 4  Jew (Palestinian Territory, Occupied)
#
#                                       Target Sectors  \
# 0                                                NaN
# 1        Elite,Executive,Executive Office,Government
# 2      General Population / Civilian / Social,Social
# 3                                                NaN
# 4  International Religious,Jewish,National Religi...
#
#                    Target Country  Story ID  Sentence Number  \
# 0                         Germany  56697949                5
# 1  Occupied Palestinian Territory  56697949                5
# 2                          Israel  56697950                5
# 3  Occupied Palestinian Territory  56697952                4
# 4  Occupied Palestinian Territory  56697952                5
#
#             Publisher       City District            Province  Country  \
# 0  The Jerusalem Post     Berlin      NaN         Land Berlin  Germany
# 1  The Jerusalem Post     Berlin      NaN         Land Berlin  Germany
# 2  The Jerusalem Post  Jerusalem      NaN  Jerusalem District   Israel
# 3  The Jerusalem Post        NaN      NaN              Sukkot    Sudan
# 4  The Jerusalem Post        NaN      NaN              Sukkot    Sudan
#
#    Latitude  Longitude
# 0   52.5244    13.4105
# 1   52.5244    13.4105
# 2   31.7690    35.2163
# 3   20.7500    30.3500
# 4   20.7500    30.3500
#    Event ID  Event Date        Source Name  \
# 0  37592900  2023-01-03       Rahul Gandhi
# 1  37592902  2023-01-03              India
# 2  37592901  2023-01-03    Priyanka Gandhi
# 3  37582623  2023-01-11    Citizen (Nepal)
# 4  37581612  2023-01-12  Ministry (Israel)
#
#                                       Source Sectors Source Country  \
# 0  (National) Major Party,Government,Government M...          India
# 1                                                NaN          India
# 2  (National) Major Party,Government Major Party ...          India
# 3      General Population / Civilian / Social,Social          Nepal
# 4                                         Government         Israel
#
#              Event Text  CAMEO Code  Intensity            Target Name  \
# 0          Make a visit          42        1.9                  India
# 1          Host a visit          43        2.8           Rahul Gandhi
# 2     Praise or endorse          51        3.4       Bharatiya Janata
# 3  Demonstrate or rally         141       -6.5      Unspecified Actor
# 4               Consult          40        1.0  Rabbi (North America)
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                                NaN          India  56745643
# 1  (National) Major Party,Government,Government M...          India  56745643
# 2  (National) Major Party,Opposition Major Party ...          India  56745643
# 3                                        Unspecified            NaN  56722182
# 4  International Religious,Jewish,National Religi...            NaN  56719884
#
#    Sentence Number           Publisher                City         District  \
# 0                1     Hindustan Times           New Delhi              NaN
# 1                1     Hindustan Times           New Delhi              NaN
# 2                6     Hindustan Times                Loni              NaN
# 3                1          Al Arabiya                 NaN              NaN
# 4                1  The Jerusalem Post  Yeshiva University  New York County
#
#                               Province        Country  Latitude  Longitude
# 0  National Capital Territory of Delhi          India   28.6358    77.2244
# 1  National Capital Territory of Delhi          India   28.6358    77.2244
# 2               State of Uttar Pradesh          India   28.7515    77.2880
# 3                                  NaN          Nepal   27.7017    85.3206
# 4                    state of New York  United States   40.8520   -73.9285
#    Event ID  Event Date                            Source Name  \
# 0  37607669  2023-01-01                       Citizen (Brazil)
# 1  37607670  2023-01-01  Military Personnel - Special (Brazil)
# 2  37607671  2023-01-01                                 Brazil
# 3  37607621  2023-01-01                         Jair Bolsonaro
# 4  37607622  2023-01-01                          United States
#
#                                   Source Sectors Source Country  \
# 0  General Population / Civilian / Social,Social         Brazil
# 1                            Government,Military         Brazil
# 2                                            NaN         Brazil
# 3    Elite,Executive,Executive Office,Government         Brazil
# 4                                            NaN  United States
#
#                                     Event Text  CAMEO Code  Intensity  \
# 0                     Make pessimistic comment          12       -0.4
# 1                                  Investigate          90       -2.0
# 2  Arrest, detain, or charge with legal action         173       -5.0
# 3                                 Make a visit          42        1.9
# 4                                 Host a visit          43        2.8
#
#                  Target Name  \
# 0        Government (Brazil)
# 1                     Brazil
# 2  Luiz Inacio Lula Da Silva
# 3              United States
# 4             Jair Bolsonaro
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                         Government         Brazil  56776618
# 1                                                NaN         Brazil  56776623
# 2  (National) Major Party,Elite,Far Left,Ideologi...         Brazil  56776625
# 3                                                NaN  United States  56776635
# 4        Elite,Executive,Executive Office,Government         Brazil  56776635
#
#    Sentence Number           Publisher       City   District  \
# 0                1  Folha de São Paulo  Sao Paulo  Sao Paulo
# 1                6  Folha de São Paulo  Esplanada      Icara
# 2                1  Folha de São Paulo   Curitiba   Curitiba
# 3                5  Folha de São Paulo        NaN        NaN
# 4                5  Folha de São Paulo        NaN        NaN
#
#                    Province        Country  Latitude  Longitude
# 0       Estado de Sao Paulo         Brazil  -23.5475   -46.6361
# 1  Estado de Santa Catarina         Brazil  -28.7000   -49.1833
# 2          Estado do Parana         Brazil  -25.4278   -49.2731
# 3                       NaN  United States   38.8951   -77.0364
# 4                       NaN  United States   38.8951   -77.0364
#    Event ID  Event Date                                        Source Name  \
# 0  37619389  2023-01-06                                   Ministry (India)
# 1  37619390  2023-01-06                           Attorney General (India)
# 2  37619388  2023-01-06  Cabinet / Council of Ministers / Advisors (India)
# 3  37619444  2023-01-07                                     Police (India)
# 4  37619364  2023-01-07                                    Citizen (India)
#
#                                   Source Sectors Source Country  \
# 0                                     Government          India
# 1                            Government,Judicial          India
# 2                   Cabinet,Executive,Government          India
# 3                              Government,Police          India
# 4  General Population / Civilian / Social,Social          India
#
#                             Event Text  CAMEO Code  Intensity  \
# 0                              Consult          40        1.0
# 1                              Consult          40        1.0
# 2                       Make statement          10        0.0
# 3      Use conventional military force         190      -10.0
# 4  Express intent to meet or negotiate          36        4.0
#
#                 Target Name                                 Target Sectors  \
# 0  Attorney General (India)                            Government,Judicial
# 1          Ministry (India)                                     Government
# 2        Government (India)                                     Government
# 3               Men (India)  General Population / Civilian / Social,Social
# 4                     Japan                                            NaN
#
#   Target Country  Story ID  Sentence Number        Publisher       City  \
# 0          India  56799914                1  Hindustan Times       Pune
# 1          India  56799914                1  Hindustan Times       Pune
# 2          India  56799914                3  Hindustan Times       Pune
# 3          India  56799911                1  Hindustan Times  Mangalore
# 4          Japan  56799912                6  Hindustan Times        NaN
#
#           District              Province Country  Latitude  Longitude
# 0  Satara Division  State of Maharashtra   India   18.5196    73.8553
# 1  Satara Division  State of Maharashtra   India   18.5196    73.8553
# 2  Satara Division  State of Maharashtra   India   18.5196    73.8553
# 3              NaN    State of Karnataka   India   12.9172    74.8560
# 4              NaN                   NaN   India   28.6358    77.2244
#    Event ID  Event Date                   Source Name  \
# 0  37634486  2023-02-01  Head of Government (Vietnam)
# 1  37629598  2023-02-02                        Israel
# 2  37629599  2023-02-02                         Syria
# 3  37629600  2023-02-02                       Lebanon
# 4  37629601  2023-02-02                         Syria
#
#                           Source Sectors Source Country  \
# 0  Executive,Executive Office,Government        Vietnam
# 1                                    NaN         Israel
# 2                                    NaN          Syria
# 3                                    NaN        Lebanon
# 4                                    NaN          Syria
#
#                             Event Text  CAMEO Code  Intensity  \
# 0  Express intent to meet or negotiate          36        4.0
# 1                              Consult          40        1.0
# 2                              Consult          40        1.0
# 3                              Consult          40        1.0
# 4                              Consult          40        1.0
#
#          Target Name                                 Target Sectors  \
# 0  Citizen (Vietnam)  General Population / Civilian / Social,Social
# 1            Lebanon                                            NaN
# 2            Lebanon                                            NaN
# 3             Israel                                            NaN
# 4             Israel                                            NaN
#
#   Target Country  Story ID  Sentence Number           Publisher          City  \
# 0        Vietnam  56832827                4             Unknown         Hanoi
# 1        Lebanon  56821249                4  The Jerusalem Post  Rosh Hanikra
# 2        Lebanon  56821249                4  The Jerusalem Post  Rosh Hanikra
# 3         Israel  56821249                4  The Jerusalem Post  Rosh Hanikra
# 4         Israel  56821249                4  The Jerusalem Post  Rosh Hanikra
#
#   District           Province  Country  Latitude  Longitude
# 0      NaN   Thanh Pho Ha Noi  Vietnam   21.0245    105.841
# 1      NaN  Northern District   Israel   33.0928     35.106
# 2      NaN  Northern District   Israel   33.0928     35.106
# 3      NaN  Northern District   Israel   33.0928     35.106
# 4      NaN  Northern District   Israel   33.0928     35.106
#    Event ID  Event Date                   Source Name  \
# 0  37634486  2023-02-01  Head of Government (Vietnam)
# 1  37629598  2023-02-02                        Israel
# 2  37629599  2023-02-02                         Syria
# 3  37629600  2023-02-02                       Lebanon
# 4  37629601  2023-02-02                         Syria
#
#                           Source Sectors Source Country  \
# 0  Executive,Executive Office,Government        Vietnam
# 1                                    NaN         Israel
# 2                                    NaN          Syria
# 3                                    NaN        Lebanon
# 4                                    NaN          Syria
#
#                             Event Text  CAMEO Code  Intensity  \
# 0  Express intent to meet or negotiate          36        4.0
# 1                              Consult          40        1.0
# 2                              Consult          40        1.0
# 3                              Consult          40        1.0
# 4                              Consult          40        1.0
#
#          Target Name                                 Target Sectors  \
# 0  Citizen (Vietnam)  General Population / Civilian / Social,Social
# 1            Lebanon                                            NaN
# 2            Lebanon                                            NaN
# 3             Israel                                            NaN
# 4             Israel                                            NaN
#
#   Target Country  Story ID  Sentence Number           Publisher          City  \
# 0        Vietnam  56832827                4             Unknown         Hanoi
# 1        Lebanon  56821249                4  The Jerusalem Post  Rosh Hanikra
# 2        Lebanon  56821249                4  The Jerusalem Post  Rosh Hanikra
# 3         Israel  56821249                4  The Jerusalem Post  Rosh Hanikra
# 4         Israel  56821249                4  The Jerusalem Post  Rosh Hanikra
#
#   District           Province  Country  Latitude  Longitude
# 0      NaN   Thanh Pho Ha Noi  Vietnam   21.0245    105.841
# 1      NaN  Northern District   Israel   33.0928     35.106
# 2      NaN  Northern District   Israel   33.0928     35.106
# 3      NaN  Northern District   Israel   33.0928     35.106
# 4      NaN  Northern District   Israel   33.0928     35.106
#    Event ID  Event Date                              Source Name  \
# 0  37656976  2023-01-27  Other Authorities / Officials (Belgium)
# 1  37656964  2023-01-27             Party Member (United States)
# 2  37656995  2023-01-27                            United States
# 3  37656945  2023-01-27                   Joseph Robinette Biden
# 4  37656944  2023-01-27                   Joseph Robinette Biden
#
#                                       Source Sectors Source Country  \
# 0                                         Government        Belgium
# 1                                            Parties  United States
# 2                                                NaN  United States
# 3  (National) Major Party,Cabinet,Center Left,Exe...  United States
# 4  (National) Major Party,Cabinet,Center Left,Exe...  United States
#
#                                    Event Text  CAMEO Code  Intensity  \
# 0  Express intent to provide humanitarian aid         333        5.2
# 1                     Make optimistic comment          13        0.4
# 2                        Provide economic aid          71        7.4
# 3         Express intent to meet or negotiate          36        4.0
# 4      Express intent to provide material aid          33        5.2
#
#             Target Name Target Sectors      Target Country  Story ID  \
# 0  Government (Ukraine)     Government             Ukraine  56881416
# 1                Russia            NaN  Russian Federation  56881418
# 2               Ukraine            NaN             Ukraine  56881419
# 3               Ukraine            NaN             Ukraine  56881428
# 4               Ukraine            NaN             Ukraine  56881428
#
#    Sentence Number Publisher    City District         Province  \
# 0                1   Unknown    Kiev      NaN      Misto Kyyiv
# 1                2   Unknown  Moscow      NaN           Moskva
# 2                1   Unknown     NaN      NaN  Washington D.C.
# 3                4   Unknown     NaN      NaN  Washington D.C.
# 4                6   Unknown     NaN      NaN              NaN
#
#               Country  Latitude  Longitude
# 0             Ukraine   50.4547    30.5238
# 1  Russian Federation   55.7522    37.6156
# 2       United States   38.9171   -77.0003
# 3       United States   38.9171   -77.0003
# 4       United States   38.8951   -77.0364
#    Event ID  Event Date                            Source Name  \
# 0  37670399  2023-01-31                              Singapore
# 1  37670400  2023-01-31                               Malaysia
# 2  37670944  2023-02-08                         Marcelo Ebrard
# 3  37665219  2023-02-14            Head of Government (Guyana)
# 4  37665684  2023-02-14  Defense / Security Ministry (Vietnam)
#
#                                       Source Sectors Source Country  \
# 0                                                NaN      Singapore
# 1                                                NaN       Malaysia
# 2  (National) Major Party,Executive,Far Left,Fore...         Mexico
# 3              Executive,Executive Office,Government         Guyana
# 4   Defense / Security Ministry,Executive,Government        Vietnam
#
#                     Event Text  CAMEO Code  Intensity Target Name  \
# 0  Express intent to cooperate          30        4.0    Malaysia
# 1  Express intent to cooperate          30        4.0   Singapore
# 2               Make statement          10        0.0      Mexico
# 3               Make statement          10        0.0      Guyana
# 4            Praise or endorse          51        3.4       Japan
#
#   Target Sectors Target Country  Story ID  Sentence Number      Publisher  \
# 0            NaN       Malaysia  56906652                1        Unknown
# 1            NaN      Singapore  56906652                1        Unknown
# 2            NaN         Mexico  56907652                4        Unknown
# 3            NaN         Guyana  56896719                1  The Oil Daily
# 4            NaN          Japan  56897657                5        Unknown
#
#      City District          Province    Country  Latitude  Longitude
# 0     NaN      NaN               NaN  Singapore   1.28967   103.8500
# 1     NaN      NaN               NaN   Malaysia   3.14309   101.6870
# 2  Felipe      NaN  Estado de Oaxaca     Mexico  16.56670   -94.6500
# 3     NaN      NaN               NaN     Guyana   6.80448   -58.1553
# 4   Hanoi      NaN  Thanh Pho Ha Noi    Vietnam  21.02450   105.8410
#    Event ID  Event Date     Source Name  \
# 0  37684856  2023-02-11     Vijay Kumar
# 1  37684857  2023-02-11          Turkey
# 2  37684676  2023-02-11   Narendra Modi
# 3  37684670  2023-02-13      Kamal Nath
# 4  37684672  2023-02-13  Priest (India)
#
#                                       Source Sectors Source Country  \
# 0  (National) Major Party,Government Major Party ...          India
# 1                                                NaN         Turkey
# 2  (National) Major Party,Dissident,Elite,Far Rig...          India
# 3  Executive,Finance / Economy / Commerce / Trade...          India
# 4                          National Religious,Social          India
#
#           Event Text  CAMEO Code  Intensity                Target Name  \
# 0       Make a visit          42        1.9                     Turkey
# 1       Host a visit          43        2.8                Vijay Kumar
# 2  Praise or endorse          51        3.4  Indigenous People (India)
# 3            Consult          40        1.0             Priest (India)
# 4            Consult          40        1.0                 Kamal Nath
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                                NaN         Turkey  56938953
# 1  (National) Major Party,Government Major Party ...          India  56938953
# 2      General Population / Civilian / Social,Social          India  56938973
# 3                          National Religious,Social          India  56938950
# 4  Executive,Finance / Economy / Commerce / Trade...          India  56938950
#
#    Sentence Number        Publisher    City         District  \
# 0                5  Hindustan Times   Avsar              NaN
# 1                5  Hindustan Times   Avsar              NaN
# 2                1  Hindustan Times  Mumbai  Konkan Division
# 3                1  Hindustan Times   Sagar              NaN
# 4                1  Hindustan Times   Sagar              NaN
#
#                   Province Country  Latitude  Longitude
# 0                    Sivas  Turkey   39.7137    38.1952
# 1                    Sivas  Turkey   39.7137    38.1952
# 2     State of Maharashtra   India   19.0728    72.8826
# 3  State of Madhya Pradesh   India   23.8425    78.7439
# 4  State of Madhya Pradesh   India   23.8425    78.7439
#    Event ID  Event Date                 Source Name  \
# 0  37697618  2023-02-13  Head of Government (Gabon)
# 1  37697725  2023-02-14                      Sweden
# 2  37697927  2023-02-14   Political Parties (India)
# 3  37698006  2023-02-14                   Amit Shah
# 4  37698008  2023-02-14               Media (India)
#
#                                       Source Sectors Source Country  \
# 0              Executive,Executive Office,Government          Gabon
# 1                                                NaN         Sweden
# 2                                            Parties          India
# 3  (National) Major Party,Government,Opposition M...          India
# 4                                       Media,Social          India
#
#                             Event Text  CAMEO Code  Intensity  \
# 0  Express intent to meet or negotiate          36        4.0
# 1  Express intent to meet or negotiate          36        4.0
# 2                    Praise or endorse          51        3.4
# 3                              Consult          40        1.0
# 4                              Consult          40        1.0
#
#                  Target Name  \
# 0  Political Parties (Gabon)
# 1            Citizen (India)
# 2         Government (India)
# 3              Media (India)
# 4                  Amit Shah
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                            Parties          Gabon  56963198
# 1      General Population / Civilian / Social,Social          India  56963046
# 2                                         Government          India  56964975
# 3                                       Media,Social          India  56964976
# 4  (National) Major Party,Government,Opposition M...          India  56964976
#
#    Sentence Number                  Publisher    City         District  \
# 0                1  Yogam Communications SARL     NaN              NaN
# 1                4            Hindustan Times  Mumbai  Konkan Division
# 2                2            Hindustan Times     NaN              NaN
# 3                1            Hindustan Times     NaN              NaN
# 4                1            Hindustan Times     NaN              NaN
#
#                Province Country  Latitude  Longitude
# 0                   NaN   Gabon   0.38333     9.4500
# 1  State of Maharashtra   India  19.07280    72.8826
# 2           Maharashtra   India  18.00000    74.0000
# 3      State of Tripura   India  24.00000    92.0000
# 4      State of Tripura   India  24.00000    92.0000
#    Event ID  Event Date               Source Name  \
# 0  37722918  2023-02-24      Government (Germany)
# 1  37722919  2023-02-24      Government (Germany)
# 2  37716728  2023-03-01                   Vietnam
# 3  37716729  2023-03-01                     Japan
# 4  37716722  2023-03-01  Bruno Rodríguez Parrilla
#
#                                   Source Sectors Source Country  \
# 0                                     Government        Germany
# 1                                     Government        Germany
# 2                                            NaN        Vietnam
# 3                                            NaN          Japan
# 4  Cabinet,Executive,Foreign Ministry,Government           Cuba
#
#                          Event Text  CAMEO Code  Intensity    Target Name  \
# 0                 Praise or endorse          51        3.4  United States
# 1                 Praise or endorse          51        3.4     World Bank
# 2  Engage in diplomatic cooperation          50        3.5          Japan
# 3  Engage in diplomatic cooperation          50        3.5        Vietnam
# 4                    Make statement          10        0.0        Vietnam
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                                NaN  United States  57018068
# 1  Global,Global Development IGOs,Global Economic...            NaN  57018068
# 2                                                NaN          Japan  57006384
# 3                                                NaN        Vietnam  57006384
# 4                                                NaN        Vietnam  57006385
#
#    Sentence Number     Publisher   City District          Province  Country  \
# 0                1  Reuters News    NaN      NaN               NaN  Germany
# 1                1  Reuters News    NaN      NaN               NaN  Germany
# 2                5       Unknown  Hanoi      NaN  Thanh Pho Ha Noi  Vietnam
# 3                5       Unknown  Hanoi      NaN  Thanh Pho Ha Noi  Vietnam
# 4                5       Unknown    NaN      NaN               NaN     Cuba
#
#    Latitude  Longitude
# 0   52.5244    13.4105
# 1   52.5244    13.4105
# 2   21.0245   105.8410
# 3   21.0245   105.8410
# 4   23.1330   -82.3830
#    Event ID  Event Date                      Source Name  \
# 0  37738837  2023-02-23       Foreign Affairs (Cameroon)
# 1  37738953  2023-02-23  Foreign Affairs (United States)
# 2  37738987  2023-02-28      Head of Government (France)
# 3  37738915  2023-03-01          Séraphin Magloire Fouda
# 4  37743107  2023-03-04          Foreign Affairs (Japan)
#
#                           Source Sectors Source Country  \
# 0  Executive,Foreign Ministry,Government       Cameroon
# 1  Executive,Foreign Ministry,Government  United States
# 2  Executive,Executive Office,Government         France
# 3  Executive,Executive Office,Government       Cameroon
# 4  Executive,Foreign Ministry,Government          Japan
#
#                             Event Text  CAMEO Code  Intensity  \
# 0            Make an appeal or request          20        3.0
# 1                          Provide aid          70        7.0
# 2  Express intent to meet or negotiate          36        4.0
# 3                       Make statement          10        0.0
# 4                         Make a visit          42        1.9
#
#                     Target Name  \
# 0  Indigenous People (Cameroon)
# 1            Citizen (Cameroon)
# 2                        Africa
# 3             Joseph Dion Ngute
# 4                         India
#
#                                       Target Sectors Target Country  Story ID  \
# 0      General Population / Civilian / Social,Social       Cameroon  57045159
# 1      General Population / Civilian / Social,Social       Cameroon  57045162
# 2                                                NaN            NaN  57045153
# 3  Cabinet,Executive,Executive Office,Foreign Min...       Cameroon  57045151
# 4                                                NaN          India  57053262
#
#    Sentence Number                  Publisher       City District  \
# 0                2  Yogam Communications SARL        NaN      NaN
# 1                1  Yogam Communications SARL     Yagoua      NaN
# 2                1  Yogam Communications SARL        NaN      NaN
# 3                6  Yogam Communications SARL    Yaounde      NaN
# 4                2                    Unknown  New Delhi      NaN
#
#                               Province                       Country  \
# 0                                  NaN                      Cameroon
# 1                     Far North Region                      Cameroon
# 2                       Central Africa  Democratic Republic of Congo
# 3                        Centre Region                      Cameroon
# 4  National Capital Territory of Delhi                         India
#
#    Latitude  Longitude
# 0   3.86667    11.5167
# 1  10.34110    15.2329
# 2  -2.02107    24.6973
# 3   3.86667    11.5167
# 4  28.63580    77.2244
#    Event ID  Event Date                         Source Name  \
# 0  37756867  2023-03-15            Organized Crime (Brazil)
# 1  37756337  2023-03-17      Undersecretary (United States)
# 2  37756338  2023-03-17  International Atomic Energy Agency
# 3  37756289  2023-03-17                    Citizen (Israel)
# 4  37750848  2023-03-18                     Aam Aadmi Party
#
#                                       Source Sectors Source Country  \
# 0                        Criminals / Gangs,Dissident         Brazil
# 1                                         Government  United States
# 2  Global,Global Diplomatic IGOs,Global Energy IG...            NaN
# 3      General Population / Civilian / Social,Social         Israel
# 4  (National) Major Party,Far Left,Ideological,Pa...          India
#
#               Event Text  CAMEO Code  Intensity                 Target Name  \
# 0         Make statement          10        0.0  Indigenous People (Brazil)
# 1         Make statement          10        0.0                        Iran
# 2         Make statement          10        0.0                        Iran
# 3   Demonstrate or rally         141       -6.5                      Israel
# 4  Criticize or denounce         111       -2.0            Bharatiya Janata
#
#                                       Target Sectors Target Country  Story ID  \
# 0      General Population / Civilian / Social,Social         Brazil  57081171
# 1                                                NaN           Iran  57079767
# 2                                                NaN           Iran  57079767
# 3                                                NaN         Israel  57079770
# 4  (National) Major Party,Opposition Major Party ...          India  57068117
#
#    Sentence Number           Publisher   City District  \
# 0                2             Unknown    NaN      NaN
# 1                3  The Jerusalem Post    NaN      NaN
# 2                5  The Jerusalem Post    NaN      NaN
# 3                1  The Jerusalem Post    NaN      NaN
# 4                1     Hindustan Times  Delhi      NaN
#
#                               Province        Country  Latitude  Longitude
# 0                    Estado de Roraima         Brazil    1.0000   -61.0000
# 1                                  NaN  United States   38.8951   -77.0364
# 2                                  NaN           Iran   35.6944    51.4215
# 3                                  NaN         Israel   31.7790    35.2253
# 4  National Capital Territory of Delhi          India   28.6538    77.2290
#    Event ID  Event Date                Source Name  \
# 0  37769843  2023-03-07                 Xi Jinping
# 1  37769906  2023-03-07              Envoy (China)
# 2  37769928  2023-03-07                   Xiao Jie
# 3  37769918  2023-03-07  World Health Organization
# 4  37769919  2023-03-07  World Health Organization
#
#                                       Source Sectors Source Country  \
# 0  (National) Major Party,Elite,Executive,Executi...          China
# 1              Executive,Foreign Ministry,Government          China
# 2              Executive,Executive Office,Government          China
# 3  Global,Global Diplomatic IGOs,Global Health IG...            NaN
# 4  Global,Global Diplomatic IGOs,Global Health IG...            NaN
#
#                                           Event Text  CAMEO Code  Intensity  \
# 0                     Engage in material cooperation          60        6.0
# 1  Appeal for easing of economic sanctions, boyco...         254       -0.3
# 2                                     Make statement          10        0.0
# 3                          Make an appeal or request          20        3.0
# 4                                       Make a visit          42        1.9
#
#            Target Name                                     Target Sectors  \
# 0       Police (China)                                  Government,Police
# 1  UN Security Council  Global,Global Defense / Security IGOs,Global D...
# 2                China                                                NaN
# 3                China                                                NaN
# 4                China                                                NaN
#
#   Target Country  Story ID  Sentence Number Publisher     City District  \
# 0          China  57108276                4   Unknown      NaN      NaN
# 1            NaN  57108280                1   Unknown      NaN      NaN
# 2          China  57108282                4   Unknown  Beijing      NaN
# 3          China  57108284                2   Unknown  Beijing      NaN
# 4          China  57108284                3   Unknown    Wuhan      NaN
#
#         Province      Country  Latitude  Longitude
# 0  Jiangsu Sheng        China   33.0000    120.000
# 1     Upper Nile  South Sudan   10.0000     32.700
# 2    Beijing Shi        China   39.9075    116.397
# 3    Beijing Shi        China   39.9075    116.397
# 4    Hubei Sheng        China   30.5833    114.267
#    Event ID  Event Date                          Source Name  \
# 0    926685  1995-01-01                   Extremist (Russia)
# 1    926687  1995-01-01  Government (Bosnia and Herzegovina)
# 2    926686  1995-01-01                     Citizen (Serbia)
# 3    926688  1995-01-01                               Canada
# 4    926689  1995-01-01             Lawyer/Attorney (Canada)
#
#                                       Source Sectors          Source Country  \
# 0  Radicals / Extremists / Fundamentalists,Dissident      Russian Federation
# 1                                         Government  Bosnia and Herzegovina
# 2      General Population / Civilian / Social,Social                  Serbia
# 3                                                NaN                  Canada
# 4                                       Legal,Social                  Canada
#
#                                     Event Text  CAMEO Code  Intensity  \
# 0                            Praise or endorse          51        3.4
# 1                  Express intent to cooperate          30        4.0
# 2                  Express intent to cooperate          30        4.0
# 3                            Praise or endorse          51        3.4
# 4  Arrest, detain, or charge with legal action         173       -5.0
#
#                            Target Name  \
# 0                        Boris Yeltsin
# 1                     Citizen (Serbia)
# 2  Government (Bosnia and Herzegovina)
# 3                  City Mayor (Canada)
# 4                      Police (Canada)
#
#                                   Target Sectors          Target Country  \
# 0    Elite,Executive,Executive Office,Government      Russian Federation
# 1  General Population / Civilian / Social,Social                  Serbia
# 2                                     Government  Bosnia and Herzegovina
# 3                     Government,Local,Municipal                  Canada
# 4                              Government,Police                  Canada
#
#    Story ID  Sentence Number         Publisher      City  District Province  \
# 0  28235806                5  The Toronto Star    Moscow       NaN   Moskva
# 1  28235807                1  The Toronto Star       NaN       NaN   Bosnia
# 2  28235807                1  The Toronto Star       NaN       NaN   Bosnia
# 3  28235809                3  The Toronto Star       NaN       NaN  Ontario
# 4  28235964                1  The Toronto Star  Montreal  Montreal   Quebec
#
#                   Country  Latitude  Longitude
# 0      Russian Federation   55.7522    37.6156
# 1  Bosnia and Herzegovina   44.0000    18.0000
# 2  Bosnia and Herzegovina   44.0000    18.0000
# 3                  Canada   49.2501   -84.4998
# 4                  Canada   45.5088   -73.5878
#    Event ID  Event Date                                    Source Name  \
# 0   1094357  1996-01-01  News Editor (Palestinian Territory, Occupied)
# 1   1094356  1996-01-01                                        Al-Quds
# 2   2549849  1996-01-01                               Citizen (Turkey)
# 3   1094358  1996-01-01                                    Jiang Zemin
# 4   1094359  1996-01-01                                   Lee Teng Hui
#
#                                       Source Sectors  \
# 0                                       Social,Media
# 1                       Social,News,Print News,Media
# 2      General Population / Civilian / Social,Social
# 3        Executive,Elite,Government,Executive Office
# 4  Executive,Elite,Executive Office,Center Right,...
#
#                    Source Country               Event Text  CAMEO Code  \
# 0  Occupied Palestinian Territory                   Accuse         112
# 1  Occupied Palestinian Territory           Make statement          10
# 2                          Turkey     Demonstrate or rally         141
# 3                           China  Make optimistic comment          13
# 4                          Taiwan             Make a visit          42
#
#    Intensity                        Target Name  \
# 0       -2.0  Palestine Liberation Organization
# 1        0.0                       Yasir Arafat
# 2       -6.5                  Unspecified Actor
# 3        0.4               Party Member (China)
# 4        1.9                      United States
#
#                           Target Sectors                  Target Country  \
# 0                      Parties,Dissident  Occupied Palestinian Territory
# 1  Executive,Government,Executive Office  Occupied Palestinian Territory
# 2                            Unspecified                             NaN
# 3                                Parties                           China
# 4                                    NaN                   United States
#
#    Story ID  Sentence Number                 Publisher       City District  \
# 0  28747362                1        The New York Times  Jerusalem      NaN
# 1  28747362                5        The New York Times  Jerusalem      NaN
# 2  28747366                2        The New York Times     Ankara      NaN
# 3  28747758                6  South China Morning Post    Beijing      NaN
# 4  28747759                2  South China Morning Post        NaN      NaN
#
#              Province        Country  Latitude  Longitude
# 0  Jerusalem District         Israel   31.7690    35.2163
# 1  Jerusalem District         Israel   31.7690    35.2163
# 2              Ankara         Turkey   39.9199    32.8543
# 3         Beijing Shi          China   39.9075   116.3970
# 4                 NaN  United States   38.8951   -77.0364
#    Event ID  Event Date                                Source Name  \
# 0   1349103  1997-01-01  Settler (Palestinian Territory, Occupied)
# 1   1349104  1997-01-01                              Boris Yeltsin
# 2   1349105  1997-01-01                           Citizen (Russia)
# 3   1349106  1997-01-01                     Kostyantyn Gryshchenko
# 4   1349107  1997-01-01                            Petru Lucinschi
#
#                                   Source Sectors  \
# 0  General Population / Civilian / Social,Social
# 1    Executive Office,Government,Elite,Executive
# 2  Social,General Population / Civilian / Social
# 3    Executive,Foreign Ministry,Government,Elite
# 4                                          Elite
#
#                    Source Country                               Event Text  \
# 0  Occupied Palestinian Territory  fight with small arms and light weapons
# 1              Russian Federation                        Praise or endorse
# 2              Russian Federation                        Praise or endorse
# 3                         Ukraine                                  Consult
# 4            Moldova, Republic of                                  Consult
#
#    CAMEO Code  Intensity                                Target Name  \
# 0         193      -10.0  Citizen (Palestinian Territory, Occupied)
# 1          51        3.4                           Citizen (Russia)
# 2          51        3.4                              Boris Yeltsin
# 3          40        1.0                            Petru Lucinschi
# 4          40        1.0                     Kostyantyn Gryshchenko
#
#                                   Target Sectors  \
# 0  General Population / Civilian / Social,Social
# 1  Social,General Population / Civilian / Social
# 2    Executive Office,Government,Elite,Executive
# 3                                          Elite
# 4    Executive,Foreign Ministry,Government,Elite
#
#                    Target Country  Story ID  Sentence Number  \
# 0  Occupied Palestinian Territory  28546456                5
# 1              Russian Federation  28546782                3
# 2              Russian Federation  28546782                3
# 3            Moldova, Republic of  28546787                6
# 4                         Ukraine  28546787                6
#
#                             Publisher      City District    Province  \
# 0          BBC Monitoring Middle East       NaN      NaN  Gaza Strip
# 1  BBC Monitoring Former Soviet Union    Moscow      NaN      Moskva
# 2  BBC Monitoring Former Soviet Union    Moscow      NaN      Moskva
# 3  BBC Monitoring Former Soviet Union  Dniester      NaN         NaN
# 4  BBC Monitoring Former Soviet Union  Dniester      NaN         NaN
#
#                           Country  Latitude  Longitude
# 0  Occupied Palestinian Territory   31.4167    34.3333
# 1              Russian Federation   55.7522    37.6156
# 2              Russian Federation   55.7522    37.6156
# 3                         Ukraine   46.3040    30.2737
# 4                         Ukraine   46.3040    30.2737
#    Event ID  Event Date                    Source Name  \
# 0   1609461  1998-01-01     Media Personnel (Colombia)
# 1   1609462  1998-01-01           Guerrilla (Colombia)
# 2   1609463  1998-01-01      Juan Carlos Wasmosy Monti
# 3   1609464  1998-01-01     Media Personnel (Paraguay)
# 4   1609465  1998-01-01  Foreign Affairs (Afghanistan)
#
#                                       Source Sectors Source Country  \
# 0                                       Social,Media       Colombia
# 1                                    Rebel,Dissident       Colombia
# 2  (National) Major Party,Parties,Executive Offic...       Paraguay
# 3                                       Social,Media       Paraguay
# 4              Foreign Ministry,Executive,Government    Afghanistan
#
#                                       Event Text  CAMEO Code  Intensity  \
# 0  Express intent to release persons or property         353        7.0
# 1                    Use unconventional violence         180       -9.0
# 2                                 Make statement          10        0.0
# 3                                 Make statement          10        0.0
# 4                                 Make statement          10        0.0
#
#                   Target Name  \
# 0         Military (Colombia)
# 1                    Colombia
# 2  Media Personnel (Paraguay)
# 3   Juan Carlos Wasmosy Monti
# 4    Government (Afghanistan)
#
#                                       Target Sectors Target Country  Story ID  \
# 0                                Military,Government       Colombia  29026231
# 1                                                NaN       Colombia  29026231
# 2                                       Social,Media       Paraguay  29026233
# 3  (National) Major Party,Parties,Executive Offic...       Paraguay  29026233
# ...
# 4                Head of Government (Taiwan)
#
#                               Target Sectors Target Country  Story ID  \
# 0                                        NaN    North Korea  43113942
# 1                                 Government          India  43113944
# 2  Environment Ministry,Executive,Government        Burundi  43113946
# 3                                        NaN  United States  43113947
# 4      Government,Executive Office,Executive         Taiwan  43113947
#
#    Sentence Number             Publisher       City         District  \
# 0                1          Reuters News        NaN              NaN
# 1                1       Hindustan Times     Mumbai  Konkan Division
# 2                1  Agence France-Presse  Bujumbura              NaN
# 3                1  Agence France-Presse        NaN              NaN
# 4                1  Agence France-Presse        NaN              NaN
#
#                     Province        Country  Latitude  Longitude
# 0                        NaN    North Korea   39.0339   125.7540
# 1       State of Maharashtra          India   19.0728    72.8826
# 2  Bujumbura Mairie Province        Burundi   -3.3822    29.3644
# 3                        NaN  United States   38.8951   -77.0364
# 4                        NaN  United States   38.8951   -77.0364
#    Event ID  Event Date                     Source Name  \
# 0  33417342  2018-01-01                     Kim Jong-Un
# 1  33417334  2018-01-01   Media Personnel (Afghanistan)
# 2  33417335  2018-01-01  Islamic Preacher (Afghanistan)
# 3  33417433  2018-01-01                  United Nations
# 4  33417502  2018-01-01            Police (Philippines)
#
#                                       Source Sectors Source Country  \
# 0  (National) Major Party,Parties,Government Majo...    North Korea
# 1                                       Social,Media    Afghanistan
# 2  Social,Muslim,National Religious,International...    Afghanistan
# 3  Global Diplomatic IGOs,International Governmen...            NaN
# 4                                  Police,Government    Philippines
#
#                         Event Text  CAMEO Code  Intensity  \
# 0                   Make statement          10        0.0
# 1                   Make statement          10        0.0
# 2        Make an appeal or request          20        3.0
# 3                   Make statement          10        0.0
# 4  Use conventional military force         190      -10.0
#
#              Target Name                                 Target Sectors  \
# 0            North Korea                                            NaN
# 1    Media (Afghanistan)                                   Social,Media
# 2  Citizen (Afghanistan)  Social,General Population / Civilian / Social
# 3     Military (Myanmar)                            Military,Government
# 4  Citizen (Philippines)  Social,General Population / Civilian / Social
#
#   Target Country  Story ID  Sentence Number                  Publisher  \
# 0    North Korea  46209924                6                 Kyodo News
# 1    Afghanistan  46209928                4  BBC Monitoring South Asia
# 2    Afghanistan  46209928                6  BBC Monitoring South Asia
# 3        Myanmar  46209932                6               Reuters News
# 4    Philippines  46209993                4  Philippine Daily Inquirer
#
#                City             District                          Province  \
# 0               NaN                  NaN                               NaN
# 1  Wuleswali Bihsud                  NaN                            Wardak
# 2               NaN                  NaN                               NaN
# 3            Sittwe                  NaN                     Rakhine State
# 4              Bato  Province of Benguet  Cordillera Administrative Region
#
#        Country  Latitude  Longitude
# 0  North Korea   39.0339   125.7540
# 1  Afghanistan   34.3436    67.9057
# 2  Afghanistan   34.4961    69.1055
# 3      Myanmar   20.1462    92.8984
# 4  Philippines   16.6137   120.9660
#    Event ID  Event Date          Source Name  \
# 0  33898801  2019-01-01  Farm Worker (India)
# 1  33898803  2019-01-01  Farm Worker (India)
# 2  33898802  2019-01-01         Bank (India)
# 3  33898809  2019-01-01       Police (India)
# 4  33898810  2019-01-01      Citizen (India)
#
#                                   Source Sectors Source Country  \
# 0                            Agricultural,Social          India
# 1                            Agricultural,Social          India
# 2                                Social,Business          India
# 3                              Police,Government          India
# 4  General Population / Civilian / Social,Social          India
#
#                                     Event Text  CAMEO Code  Intensity  \
# 0                    Make an appeal or request          20        3.0
# 1                     Rally opposition against         113       -2.0
# 2                    Make an appeal or request          20        3.0
# 3  Arrest, detain, or charge with legal action         173       -5.0
# 4                           Physically assault         182       -9.5
#
#         Target Name                                 Target Sectors  \
# 0   Citizen (India)  General Population / Civilian / Social,Social
# 1      Bank (India)                                Social,Business
# 2   Citizen (India)  General Population / Civilian / Social,Social
# 3   Citizen (India)  General Population / Civilian / Social,Social
# 4  Criminal (India)                    Dissident,Criminals / Gangs
#
#   Target Country  Story ID  Sentence Number        Publisher    City  \
# 0          India  48745933                1  Hindustan Times     NaN
# 1          India  48745933                1  Hindustan Times     NaN
# 2          India  48745933                4  Hindustan Times     NaN
# 3          India  48745934                1  Hindustan Times  Jaipur
# 4          India  48745934                5  Hindustan Times  Jaipur
#
#     District            Province Country  Latitude  Longitude
# 0  Bharatpur  State of Rajasthan   India   27.2100    77.2900
# 1  Bharatpur  State of Rajasthan   India   27.2100    77.2900
# 2  Bharatpur  State of Rajasthan   India   27.2100    77.2900
# 3     Jaipur  State of Rajasthan   India   26.9196    75.7878
# 4     Jaipur  State of Rajasthan   India   26.9196    75.7878
#    Event ID  Event Date               Source Name  \
# 0  34755012  2020-01-01  Military Police (Brazil)
# 1  34755106  2020-01-01            Jair Bolsonaro
# 2  34755107  2020-01-01                    Taiwan
# 3  34754112  2020-01-01                  Honduras
# 4  34754106  2020-01-01                  Honduras
#
#                                 Source Sectors Source Country  \
# 0                          Military,Government         Brazil
# 1  Elite,Executive,Executive Office,Government         Brazil
# 2                                          NaN         Taiwan
# 3                                          NaN       Honduras
# 4                                          NaN       Honduras
#
#                         Event Text  CAMEO Code  Intensity     Target Name  \
# 0  Use conventional military force         190      -10.0    Men (Brazil)
# 1                     Make a visit          42        1.9          Taiwan
# 2                     Host a visit          43        2.8  Jair Bolsonaro
# 3            Sign formal agreement          57        8.0       Guatemala
# 4            Sign formal agreement          57        8.0          Mexico
#
#                                   Target Sectors Target Country  Story ID  \
# 0  Social,General Population / Civilian / Social         Brazil  50046377
# 1                                            NaN         Taiwan  50046415
# 2    Elite,Executive,Executive Office,Government         Brazil  50046415
# 3                                            NaN      Guatemala  50046429
# 4                                            NaN         Mexico  50046429
#
#    Sentence Number             Publisher  City District             Province  \
# 0                1               O Globo  Embu     Embu  Estado de Sao Paulo
# 1                3    Folha de São Paulo   NaN      NaN                  NaN
# 2                3    Folha de São Paulo   NaN      NaN                  NaN
# 3                6  Agence France-Presse   NaN      NaN      Central America
# 4                6  Agence France-Presse   NaN      NaN      Central America
#
#   Country  Latitude  Longitude
# 0  Brazil  -23.6489   -46.8522
# 1  Taiwan   24.9470   121.5820
# 2  Taiwan   24.9470   121.5820
# 3  Mexico   25.3242   -99.6680
# 4  Mexico   25.3242   -99.6680
#    Event ID  Event Date                 Source Name  \
# 0  35799758  2021-01-01            Bharatiya Janata
# 1  35799759  2021-01-01            Bharatiya Janata
# 2  35799760  2021-01-01            Bharatiya Janata
# 3  35799761  2021-01-01  Head of Government (India)
# 4  35799762  2021-01-01              Police (India)
#
#                                       Source Sectors Source Country  \
# 0  (National) Major Party,Opposition Major Party ...          India
# 1  (National) Major Party,Opposition Major Party ...          India
# 2  (National) Major Party,Opposition Major Party ...          India
# 3              Executive Office,Government,Executive          India
# 4                                  Government,Police          India
#
#                                        Event Text  CAMEO Code  Intensity  \
# 0                                  Make statement          10        0.0
# 1                               Praise or endorse          51        3.4
# 2                                          Reject         120       -4.0
# 3  Reject proposal to meet, discuss, or negotiate         125       -5.0
# 4     Arrest, detain, or charge with legal action         173       -5.0
#
#            Target Name                                 Target Sectors  \
# 0   Government (India)                                     Government
# 1  Legislature (India)         Government,Legislative / Parliamentary
# 2  Legislature (India)         Government,Legislative / Parliamentary
# 3  Farm Worker (India)                            Agricultural,Social
# 4          Men (India)  Social,General Population / Civilian / Social
#
#   Target Country  Story ID  Sentence Number                Publisher  \
# 0          India  52359185                1          Hindustan Times
# 1          India  52359185                1          Hindustan Times
# 2          India  52359185                2          Hindustan Times
# 3          India  52359185                6          Hindustan Times
# 4          India  52359188                1  Indo-Asian News Service
#
#         City District                 Province Country  Latitude  Longitude
# 0        NaN      NaN          State of Kerala   India   10.0000    76.5000
# 1        NaN      NaN          State of Kerala   India   10.0000    76.5000
# 2        NaN      NaN          State of Kerala   India   10.0000    76.5000
# 3        NaN      NaN          State of Kerala   India   10.0000    76.5000
# 4  Gorakhpur      NaN  State of Madhya Pradesh   India   22.7494    81.4407
#    Event ID  Event Date           Source Name  \
# 0  36615529  2022-01-01           South Korea
# 1  36615519  2022-01-01  Ministry (Indonesia)
# 2  36615520  2022-01-01         Denis Moncada
# 3  36615521  2022-01-01         Denis Moncada
# 4  36615523  2022-01-01                 China
#
#                           Source Sectors Source Country         Event Text  \
# 0                                    NaN    South Korea      Demand rights
# 1                             Government      Indonesia             Reject
# 2  Executive,Foreign Ministry,Government      Nicaragua       Host a visit
# 3  Executive,Foreign Ministry,Government      Nicaragua  Praise or endorse
# 4                                    NaN          China       Make a visit
#
#    CAMEO Code  Intensity               Target Name  \
# 0        1043       -5.0  Government (South Korea)
# 1         120       -4.0                   Reuters
# 2          43        2.8                     China
# 3          51        3.4   Foreign Affairs (China)
# 4          42        1.9             Denis Moncada
#
#                           Target Sectors  Target Country  Story ID  \
# 0                             Government     South Korea  54339603
# 1                      Media,News,Social  United Kingdom  54339616
# 2                                    NaN           China  54339617
# 3  Executive,Foreign Ministry,Government           China  54339617
# 4  Executive,Foreign Ministry,Government       Nicaragua  54339617
#
#    Sentence Number            Publisher     City District  \
# 0                2  Yonhap English News    Seoul      NaN
# 1                2              Unknown  Jakarta      NaN
# 2                1   Al Jazeera English  Managua      NaN
# 3                1   Al Jazeera English  Managua      NaN
# 4                1   Al Jazeera English  Managua      NaN
#
#                         Province      Country  Latitude  Longitude
# 0              Seoul-teukbyeolsi  South Korea  37.56830   126.9780
# 1  Daerah Khusus Ibukota Jakarta    Indonesia  -6.21462   106.8450
# 2        Departamento de Managua    Nicaragua  12.13280   -86.2504
# 3        Departamento de Managua    Nicaragua  12.13280   -86.2504
# 4        Departamento de Managua    Nicaragua  12.13280   -86.2504
#    Event ID  Event Date                                Source Name  \
# 0  37530852  2023-01-01  Defense / Security Ministry (South Korea)
# 1  37530790  2023-01-01      Defense / Security Ministry (Ukraine)
# 2  37530846  2023-01-01       Defense / Security Ministry (Russia)
# 3  37530848  2023-01-01                          Military (Russia)
# 4  37530847  2023-01-01                                    Ukraine
#
#                                      Source Sectors      Source Country  \
# 0  Defense / Security Ministry,Executive,Government         South Korea
# 1  Defense / Security Ministry,Executive,Government             Ukraine
# 2  Defense / Security Ministry,Executive,Government  Russian Federation
# 3                               Government,Military  Russian Federation
# 4                                               NaN             Ukraine
#
#                                 Event Text  CAMEO Code  Intensity  \
# 0                           Make statement          10        0.0
# 1                           Make statement          10        0.0
# 2                           Make statement          10        0.0
# 3  fight with small arms and light weapons         193      -10.0
# 4          Use conventional military force         190      -10.0
#
#          Target Name       Target Sectors      Target Country  Story ID  \
# 0        North Korea                  NaN         North Korea  56602964
# 1             Russia                  NaN  Russian Federation  56602966
# 2  Military (Russia)  Government,Military  Russian Federation  56602970
# 3            Ukraine                  NaN             Ukraine  56602970
# 4             Russia                  NaN  Russian Federation  56602970
#
#    Sentence Number Publisher   City District     Province             Country  \
# 0                1   Unknown    NaN      NaN          NaN         South Korea
# 1                6   Unknown  Minsk      NaN  Horad Minsk             Belarus
# 2                1   Unknown    NaN      NaN          NaN  Russian Federation
# 3                1   Unknown    NaN      NaN          NaN             Ukraine
# 4                3   Unknown    NaN      NaN          NaN  Russian Federation
#
#    Latitude  Longitude
# 0   37.5683   126.9780
# 1   53.9000    27.5667
# 2   55.7522    37.6156
# 3   50.4547    30.5238
# 4   55.7522    37.6156
# 20420308

# %%
df_main.shape
# Out:
# (20420308, 20)

# %%
df_main['Event Date'].min()
# Out:
# '1995-01-01'

# %%
df_main['Event Date'].max()
# Out:
# '2023-04-10'

# %%
df.shape
# Out:
# (3155, 20)

# %%
df['Event Date'].min()
# Out:
# '2023-01-01'

# %%
df_main =df_main[df_main['Country'] == 'Russian Federation']

# %%
df_main.head()
# Out:
#     Event ID  Event Date       Source Name  \
# 9   37542234  2022-10-14       Middle East
# 32  37536358  2022-10-18    United Nations
# 33  37536357  2022-10-18            Russia
# 45  37536359  2022-10-18            Israel
# 55  37538604  2022-10-18  Citizen (Russia)
#
#                                        Source Sectors      Source Country  \
# 9                                                 NaN                 NaN
# 32  Global,Global Diplomatic IGOs,International Go...                 NaN
# 33                                                NaN  Russian Federation
# 45                                                NaN              Israel
# 55      General Population / Civilian / Social,Social  Russian Federation
#
#                                 Event Text CAMEO Code  Intensity  \
# 9                    Criticize or denounce        111       -2.0
# 32                   Criticize or denounce        111       -2.0
# 33                Make pessimistic comment         12       -0.4
# 45  Express intent to provide military aid        332        5.2
# 55                   Criticize or denounce        111       -2.0
#
#              Target Name Target Sectors      Target Country  Story ID  \
# 9                 Russia            NaN  Russian Federation  56633063
# 32                Russia            NaN  Russian Federation  56617379
# 33                Israel            NaN              Israel  56617379
# 45  Government (Ukraine)     Government             Ukraine  56617388
# 55                Russia            NaN  Russian Federation  56623802
#
#     Sentence Number           Publisher    City District Province  \
# 9                 4  The Jerusalem Post     NaN      NaN      NaN
# 32                3  The Jerusalem Post  Moscow      NaN   Moskva
# 33                6  The Jerusalem Post  Moscow      NaN   Moskva
# 45                2  The Jerusalem Post  Moscow      NaN   Moskva
# 55                2             Unknown  Moscow      NaN   Moskva
#
#                Country  Latitude  Longitude
# 9   Russian Federation   55.7522    37.6156
# 32  Russian Federation   55.7522    37.6156
# 33  Russian Federation   55.7522    37.6156
# 45  Russian Federation   55.7522    37.6156
# 55  Russian Federation   55.7522    37.6156

# %%
import datetime as dt
df_main['Event Date'] = pd.to_datetime(df['Event Date'])
# Out:
# C:\Users\nomad\AppData\Local\Temp\ipykernel_23620\3881814779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main['Event Date'] = pd.to_datetime(df['Event Date'])

# %%
df_main.describe()
# Out:
#            Event ID     Intensity      Story ID  Sentence Number  \
# count  1.199583e+06  1.199583e+06  1.199583e+06     1.199583e+06
# mean   1.702705e+07  7.628834e-01  2.521502e+07     2.813226e+00
# std    1.249740e+07  4.049109e+00  1.919310e+07     1.688051e+00
# min    9.266850e+05 -1.000000e+01  3.000000e+01     1.000000e+00
# 25%    5.662851e+06  0.000000e+00  6.317384e+06     1.000000e+00
# 50%    1.368285e+07  1.000000e+00  2.878091e+07     2.000000e+00
# 75%    3.057441e+07  3.400000e+00  4.291442e+07     4.000000e+00
# max    3.778357e+07  1.000000e+01  5.713170e+07     6.000000e+00
#
#            Latitude     Longitude
# count  1.199583e+06  1.199583e+06
# mean   5.447692e+01  4.097429e+01
# std    4.139570e+00  1.518493e+01
# min    4.128410e+01 -1.796670e+02
# 25%    5.575220e+01  3.761560e+01
# 50%    5.575220e+01  3.761560e+01
# 75%    5.575220e+01  3.761560e+01
# max    7.500000e+01  1.782170e+02

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1199583 entries, 9 to 3132
# Data columns (total 20 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Event ID         1199583 non-null  int64
#  1   Event Date       7389 non-null     datetime64[ns]
#  2   Source Name      1199583 non-null  object
#  3   Source Sectors   869873 non-null   object
#  4   Source Country   1154624 non-null  object
#  5   Event Text       1199583 non-null  object
#  6   CAMEO Code       1199583 non-null  object
#  7   Intensity        1199583 non-null  float64
#  8   Target Name      1199583 non-null  object
#  9   Target Sectors   726627 non-null   object
#  10  Target Country   1136691 non-null  object
#  11  Story ID         1199583 non-null  int64
#  12  Sentence Number  1199583 non-null  int64
#  13  Publisher        1199583 non-null  object
#  14  City             994700 non-null   object
#  15  District         44708 non-null    object
#  16  Province         1044117 non-null  object
#  17  Country          1199583 non-null  object
#  18  Latitude         1199583 non-null  float64
#  19  Longitude        1199583 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(13)
# memory usage: 192.2+ MB

# %%
df_main.shape
# Out:
# (1199583, 20)

# %%
df_main['Event Date'].min()
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
# df_main.nunique()
from copy import deepcopy
# for i in df_main.columns():
#     df_main[f'{i}_u']
df_main1 = deepcopy(df_main)
df_main1.drop_duplicates()
# Out:
#       Event ID  Event Date                           Source Name  \
# 9     37542234  2022-10-14                           Middle East
# 32    37536358  2022-10-18                        United Nations
# 33    37536357  2022-10-18                                Russia
# 45    37536359  2022-10-18                                Israel
# 55    37538604  2022-10-18                      Citizen (Russia)
# ...        ...         ...                                   ...
# 2971  37532178  2023-01-03  Defense / Security Ministry (Russia)
# 2972  37532494  2023-01-03                               Ukraine
# 3107  37532350  2023-01-03  Defense / Security Ministry (Russia)
# 3109  37532359  2023-01-03                    Military (Ukraine)
# 3132  37532601  2023-01-03  Defense / Security Ministry (Russia)
#
#                                          Source Sectors      Source Country  \
# 9                                                   NaN                 NaN
# 32    Global,Global Diplomatic IGOs,International Go...                 NaN
# 33                                                  NaN  Russian Federation
# 45                                                  NaN              Israel
# 55        General Population / Civilian / Social,Social  Russian Federation
# ...                                                 ...                 ...
# 2971   Defense / Security Ministry,Executive,Government  Russian Federation
# 2972                                                NaN             Ukraine
# 3107   Defense / Security Ministry,Executive,Government  Russian Federation
# 3109                                Government,Military             Ukraine
# 3132   Defense / Security Ministry,Executive,Government  Russian Federation
#
#                                   Event Text CAMEO Code  Intensity  \
# 9                      Criticize or denounce        111       -2.0
# 32                     Criticize or denounce        111       -2.0
# 33                  Make pessimistic comment         12       -0.4
# 45    Express intent to provide military aid        332        5.2
# 55                     Criticize or denounce        111       -2.0
# ...                                      ...        ...        ...
# 2971                          Make statement         10        0.0
# 2972         Use conventional military force        190      -10.0
# 3107                          Make statement         10        0.0
# 3109         Use conventional military force        190      -10.0
# 3132                          Make statement         10        0.0
#
#                Target Name       Target Sectors      Target Country  Story ID  \
# 9                   Russia                  NaN  Russian Federation  56633063
# 32                  Russia                  NaN  Russian Federation  56617379
# 33                  Israel                  NaN              Israel  56617379
# 45    Government (Ukraine)           Government             Ukraine  56617388
# 55                  Russia                  NaN  Russian Federation  56623802
# ...                    ...                  ...                 ...       ...
# 2971     Military (Russia)  Government,Military  Russian Federation  56607805
# 2972                Russia                  NaN  Russian Federation  56607853
# 3107    Military (Ukraine)  Government,Military             Ukraine  56608467
# 3109     Military (Russia)  Government,Military  Russian Federation  56608467
# 3132     Military (Russia)  Government,Military  Russian Federation  56608637
#
#       Sentence Number             Publisher       City District  \
# 9                   4    The Jerusalem Post        NaN      NaN
# 32                  3    The Jerusalem Post     Moscow      NaN
# 33                  6    The Jerusalem Post     Moscow      NaN
# 45                  2    The Jerusalem Post     Moscow      NaN
# 55                  2               Unknown     Moscow      NaN
# ...               ...                   ...        ...      ...
# 2971                3  Agence France-Presse     Moscow      NaN
# 2972                1         Straits Times     Moscow      NaN
# 3107                1               Unknown        NaN      NaN
# 3109                1               Unknown        NaN      NaN
# 3132                1               Unknown  Makeyevka      NaN
#
#            Province             Country  Latitude  Longitude
# 9               NaN  Russian Federation   55.7522    37.6156
# 32           Moskva  Russian Federation   55.7522    37.6156
# 33           Moskva  Russian Federation   55.7522    37.6156
# 45           Moskva  Russian Federation   55.7522    37.6156
# 55           Moskva  Russian Federation   55.7522    37.6156
# ...             ...                 ...       ...        ...
# 2971         Moskva  Russian Federation   55.7522    37.6156
# 2972         Moskva  Russian Federation   55.7522    37.6156
# 3107            NaN  Russian Federation   55.7522    37.6156
# 3109            NaN  Russian Federation   55.7522    37.6156
# 3132  Bashkortostan  Russian Federation   53.3833    55.5833
#
# [1198040 rows x 20 columns]

# %%
print(df_main.nunique())

print('+++++++++++++++++++++++++++++++++++++')
print(df_main1.nunique())
# Out:
# Event ID           1197781
# Event Date           10267
# Source Name          11925
# Source Sectors       33426
# Source Country         210
# Event Text             256
# CAMEO Code             428
# Intensity               41
# Target Name          11616
# Target Sectors       29915
# Target Country         211
# Story ID            627997
# Sentence Number          6
# Publisher              250
# City                  3350
# District                59
# Province               102
# Country                  1
# Latitude              3322
# Longitude             3443
# dtype: int64
# +++++++++++++++++++++++++++++++++++++
# Event ID           1197781
# Event Date           10267
# Source Name          11925
# Source Sectors       33426
# Source Country         210
# Event Text             256
# CAMEO Code             428
# Intensity               41
# Target Name          11616
# Target Sectors       29915
# Target Country         211
# Story ID            627997
# Sentence Number          6
# Publisher              250
# City                  3350
# District                59
# Province               102
# Country                  1
# Latitude              3322
# Longitude             3443
# dtype: int64

# %%
print(df_main)
print(df_main1.shape)
df_main = df_main1
# Out:
#       Event ID  Event Date                           Source Name  \
# 9     37542234  2022-10-14                           Middle East
# 32    37536358  2022-10-18                        United Nations
# 33    37536357  2022-10-18                                Russia
# 45    37536359  2022-10-18                                Israel
# 55    37538604  2022-10-18                      Citizen (Russia)
# ...        ...         ...                                   ...
# 2971  37532178  2023-01-03  Defense / Security Ministry (Russia)
# 2972  37532494  2023-01-03                               Ukraine
# 3107  37532350  2023-01-03  Defense / Security Ministry (Russia)
# 3109  37532359  2023-01-03                    Military (Ukraine)
# 3132  37532601  2023-01-03  Defense / Security Ministry (Russia)
#
#                                          Source Sectors      Source Country  \
# 9                                                   NaN                 NaN
# 32    Global,Global Diplomatic IGOs,International Go...                 NaN
# 33                                                  NaN  Russian Federation
# 45                                                  NaN              Israel
# 55        General Population / Civilian / Social,Social  Russian Federation
# ...                                                 ...                 ...
# 2971   Defense / Security Ministry,Executive,Government  Russian Federation
# 2972                                                NaN             Ukraine
# 3107   Defense / Security Ministry,Executive,Government  Russian Federation
# 3109                                Government,Military             Ukraine
# 3132   Defense / Security Ministry,Executive,Government  Russian Federation
#
#                                   Event Text CAMEO Code  Intensity  \
# 9                      Criticize or denounce        111       -2.0
# 32                     Criticize or denounce        111       -2.0
# 33                  Make pessimistic comment         12       -0.4
# 45    Express intent to provide military aid        332        5.2
# 55                     Criticize or denounce        111       -2.0
# ...                                      ...        ...        ...
# 2971                          Make statement         10        0.0
# 2972         Use conventional military force        190      -10.0
# 3107                          Make statement         10        0.0
# 3109         Use conventional military force        190      -10.0
# 3132                          Make statement         10        0.0
#
#                Target Name       Target Sectors      Target Country  Story ID  \
# 9                   Russia                  NaN  Russian Federation  56633063
# 32                  Russia                  NaN  Russian Federation  56617379
# 33                  Israel                  NaN              Israel  56617379
# 45    Government (Ukraine)           Government             Ukraine  56617388
# 55                  Russia                  NaN  Russian Federation  56623802
# ...                    ...                  ...                 ...       ...
# 2971     Military (Russia)  Government,Military  Russian Federation  56607805
# 2972                Russia                  NaN  Russian Federation  56607853
# 3107    Military (Ukraine)  Government,Military             Ukraine  56608467
# 3109     Military (Russia)  Government,Military  Russian Federation  56608467
# 3132     Military (Russia)  Government,Military  Russian Federation  56608637
#
#       Sentence Number             Publisher       City District  \
# 9                   4    The Jerusalem Post        NaN      NaN
# 32                  3    The Jerusalem Post     Moscow      NaN
# 33                  6    The Jerusalem Post     Moscow      NaN
# 45                  2    The Jerusalem Post     Moscow      NaN
# 55                  2               Unknown     Moscow      NaN
# ...               ...                   ...        ...      ...
# 2971                3  Agence France-Presse     Moscow      NaN
# 2972                1         Straits Times     Moscow      NaN
# 3107                1               Unknown        NaN      NaN
# 3109                1               Unknown        NaN      NaN
# 3132                1               Unknown  Makeyevka      NaN
#
#            Province             Country  Latitude  Longitude
# 9               NaN  Russian Federation   55.7522    37.6156
# 32           Moskva  Russian Federation   55.7522    37.6156
# 33           Moskva  Russian Federation   55.7522    37.6156
# 45           Moskva  Russian Federation   55.7522    37.6156
# 55           Moskva  Russian Federation   55.7522    37.6156
# ...             ...                 ...       ...        ...
# 2971         Moskva  Russian Federation   55.7522    37.6156
# 2972         Moskva  Russian Federation   55.7522    37.6156
# 3107            NaN  Russian Federation   55.7522    37.6156
# 3109            NaN  Russian Federation   55.7522    37.6156
# 3132  Bashkortostan  Russian Federation   53.3833    55.5833
#
# [1199583 rows x 20 columns]
# (1199583, 20)

# %%
df_main['Event Date'].min()
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
df_main.to_csv(r'C:\Users\nomad\Downloads\mainpy\df_main1.csv', sep=";")

# %%
df_main2 = pd.read_csv(r'C:\Users\nomad\Downloads\mainpy\df_main1.csv', sep=";")
# Out:
# C:\Users\nomad\AppData\Local\Temp\ipykernel_23620\2264764536.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_main2 = pd.read_csv(r'C:\Users\nomad\Downloads\mainpy\df_main1.csv', sep=";")

# %%
df_main2['Event Date'].min()
# Out:
# '1995-01-01'

# %%
df_main2
df_main2 = df_main2[['Event ID', 'Event Date', 'Event Text', 'Story ID', 'City', 'District', 'Province', 'Latitude', 'Longitude']]
df_main2
# Out:
#          Event ID  Event Date                              Event Text  \
# 0        37542234  2022-10-14                   Criticize or denounce
# 1        37536358  2022-10-18                   Criticize or denounce
# 2        37536357  2022-10-18                Make pessimistic comment
# 3        37536359  2022-10-18  Express intent to provide military aid
# 4        37538604  2022-10-18                   Criticize or denounce
# ...           ...         ...                                     ...
# 1199578  37532178  2023-01-03                          Make statement
# 1199579  37532494  2023-01-03         Use conventional military force
# 1199580  37532350  2023-01-03                          Make statement
# 1199581  37532359  2023-01-03         Use conventional military force
# 1199582  37532601  2023-01-03                          Make statement
#
#          Story ID       City District       Province  Latitude  Longitude
# 0        56633063        NaN      NaN            NaN   55.7522    37.6156
# 1        56617379     Moscow      NaN         Moskva   55.7522    37.6156
# 2        56617379     Moscow      NaN         Moskva   55.7522    37.6156
# 3        56617388     Moscow      NaN         Moskva   55.7522    37.6156
# 4        56623802     Moscow      NaN         Moskva   55.7522    37.6156
# ...           ...        ...      ...            ...       ...        ...
# 1199578  56607805     Moscow      NaN         Moskva   55.7522    37.6156
# 1199579  56607853     Moscow      NaN         Moskva   55.7522    37.6156
# 1199580  56608467        NaN      NaN            NaN   55.7522    37.6156
# 1199581  56608467        NaN      NaN            NaN   55.7522    37.6156
# 1199582  56608637  Makeyevka      NaN  Bashkortostan   53.3833    55.5833
#
# [1199583 rows x 9 columns]

# %%
df_main2['Event Date'].min()
# Out:
# '1995-01-01'

# %%
df_main2[df_main['Event Text'] == 'Demonstrate or rally']
# Out:
#         Event ID Event Date            Event Text  Story ID       City  \
# 7179    37534934        NaT  Demonstrate or rally  56612931     Samara
# 13673   37550452        NaT  Demonstrate or rally  56650364     Moscow
# 1816    37571701 2023-01-02  Demonstrate or rally  56698583        NaN
# 3715    37569137        NaT  Demonstrate or rally  56692930     Moscow
# 6687    37588800        NaT  Demonstrate or rally  56735679     Moscow
# ...          ...        ...                   ...       ...        ...
# 789371  37515897        NaT  Demonstrate or rally  56565804     Berkut
# 795542  37529121        NaT  Demonstrate or rally  56598911     Moscow
# 796745  37530610        NaT  Demonstrate or rally  56602523     Moscow
# 2321    37534529 2023-01-03  Demonstrate or rally  56606014     Samara
# 2322    37534530 2023-01-03  Demonstrate or rally  56606014  Tol'yatti
#
#        District               Province  Latitude  Longitude Event Date_dt  \
# 7179        NaN     Samarskaya Oblast'   53.2001    50.1500           NaT
# 13673       NaN                 Moskva   55.7522    37.6156           NaT
# 1816        NaN          North Ossetia   43.0000    44.2500    2023-01-02
# 3715        NaN                 Moskva   55.7522    37.6156           NaT
# 6687        NaN                 Moskva   55.7522    37.6156           NaT
# ...         ...                    ...       ...        ...           ...
# 789371      NaN  Orenburgskaya Oblast'   51.2921    57.7054           NaT
# 795542      NaN                 Moskva   55.7522    37.6156           NaT
# 796745      NaN                 Moskva   55.7522    37.6156           NaT
# 2321        NaN     Samarskaya Oblast'   53.2001    50.1500    2023-01-03
# 2322        NaN     Samarskaya Oblast'   53.5303    49.3461    2023-01-03
#
#         Year
# 7179     NaT
# 13673    NaT
# 1816    2023
# 3715     NaT
# 6687     NaT
# ...      ...
# 789371   NaT
# 795542   NaT
# 796745   NaT
# 2321    2023
# 2322    2023
#
# [10461 rows x 11 columns]

# %%
df_main2['Event Date'].min()
# Out:
# '1995-01-01'

# %%
import datetime as dt
df_main2['Event Date'] = pd.to_datetime(df_main2['Event Date'])
df_main2['Year']  = df_main2['Event Date'].dt.to_period("Y")
# Out:
# C:\Users\nomad\AppData\Local\Temp\ipykernel_23620\1855036878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main2['Event Date'] = pd.to_datetime(df_main2['Event Date'])
# C:\Users\nomad\AppData\Local\Temp\ipykernel_23620\1855036878.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main2['Year']  = df_main2['Event Date'].dt.to_period("Y")

# %%
df_main.groupby('Year')

# %%
import matplotlib as plt
df_main2['Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
df_main = df_main2[df_main2['Event Text'] == 'Demonstrate or rally']

# %%
df_main.groupby('Year')
df_main['Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
df_main2.to_csv(r'C:\Users\nomad\Downloads\mainpy\kursach_16.11.24.csv', sep=";")
